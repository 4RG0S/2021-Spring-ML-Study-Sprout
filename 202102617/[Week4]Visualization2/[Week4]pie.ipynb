# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = pd.read_csv('/content/drive/MyDrive/titanic/train.csv')

# %%
a.head(5)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
x = a['Sex']
y = a[a['Survived'] == 1].value_counts()
z = a[a['Survived'] == 0].value_counts()

# %%
a.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
fig, ax = plt.subplots()
ax.scatter(a['Age'], a['Fare'])
ax.set_title('Ticket_Price_Based_On_Age')
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
plt.pie(a['Sex']=='male', a['Survived']==1)
plt.show()

# %%
plt.pie(len(a['Sex']=='male'), len(a['Survived']==1))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-680283dcd6e8> in <module>()
# ----> 1 plt.pie(len(a['Sex']=='male'), len(a['Survived']==1))
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# ...

# %%
a['Sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
living = list()

# %%
living.append(len(a['Sex']=='male'))

# %%
living
# Out:
# [891]

# %%
living.append(len(a['Sex']=='Female'))

# %%
living
# Out:
# [891, 891]

# %%
living.append(len(a['Sex']))

# %%
living
# Out:
# [891, 891, 891]

# %%
living.pop()
living.pop()living.pop()
# Out:
#   File "<ipython-input-19-df84c535ffad>", line 2
#     living.pop()living.pop()
#                      ^
# SyntaxError: invalid syntax

# %%
living
# Out:
# [891, 891, 891]

# %%
living.pop()
# Out:
# 891

# %%
living.append((a['Sex']=='male').value_counts)

# %%
living
# Out:
# [891, 891, <bound method IndexOpsMixin.value_counts of 0       True
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  886     True
#  887    False
#  888    False
#  889     True
#  890     True
#  Name: Sex, Length: 891, dtype: bool>]

# %%
living.pop()
# Out:
# <bound method IndexOpsMixin.value_counts of 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool>

# %%
living
# Out:
# [891, 891]

# %%
living.pop()
living.pop()
# Out:
# 891

# %%
living
# Out:
# []

# %%
def pie_chart(feature):
  feature_ratio = a[feature].value_counts(sort = False)
  feature_size = feature_ratio.size
  feature_index = feature_ratio.index
  survived = a[a['Survived'] == 1][feature].value_counts()
  dead = a[a['Survived'] == 0][feature].value_counts()


  plt.plot(aspect = 'auto')
  plt.pie(feature_ratio, labels = feature_index, autopct='%1.1f%%')
  plt.title(feature + '\'s ratio in total')

  for i, index in enumerate(feature_index):
    plt.subplot(1, feature_size + 1, i + 1, aspect = 'equal')
    plt.pie([survived[index], dead[index]], labels = ['Survived', 'Dead'], autopct='%1.1f%%')
    plt.title(str(index) + '\'s ratio')

  plt.show()

# %%
pie_chart('Sex')

# %%
def pie_chart2(feature):
  feature_ratio = a[feature].value_counts(sort = False)
  feature_size = feature_ratio.size
  feature_index = feature_ratio.index
  survived = a[a['Survived'] == 1][feature].value_counts()
  dead = a[a['Survived'] == 0][feature].value_counts()


  plt.plot(aspect = 'auto')
  plt.pie(feature_ratio, labels = feature_index, autopct='%1.1f%%')
  plt.title(feature + '\'s ratio in total')

  plt.show()

# %%
pie_chart2('Sex')

# %%
pie_chart2('Pclass')

# %%
pie_chart('Pclass')
